# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('../data/log2.csv', index_col=0)
df.index = df.index.to_series().astype(str)
df.head()
# Out:
#          V17        V18        V19        V20        V21        V22  \
# 1  18.535093  19.899015  19.544755  20.521284  19.802305  20.203986
# 2  22.844069  23.044679  23.044687  23.233513  23.060141  23.331820
# 3        NaN  16.380613        NaN  17.445904  15.478390  16.236948
# 4  18.343468  19.834326  19.698411  20.209993  18.144977  18.179039
# 5  17.104281  17.728033  17.452957  18.138757  15.879583        NaN
#
#          V23        V24        V25        V26    ...             V7  \
# 1  20.001793  20.666181  20.902142  20.688575    ...      19.631765
# 2  23.229938  23.494385  23.591767  23.439515    ...      22.465839
# 3  16.361327  17.238797  17.457742  17.638655    ...            NaN
# 4  19.651518  19.707679  20.363331  19.768596    ...      17.372227
# 5  17.157130  17.733466  18.235336  17.863146    ...      15.537886
#
#           V8         V9        V10        V11        V12        V13  \
# 1  19.575307  19.858916  19.768514  20.877259  19.902687  19.499885
# ...

# %%
rows = ['4', '5', '6']
s1_i = [3,4,5]
s2_i = [6,7,8]

s1_df = df.ix[rows, s1_i]
s2_df = df.ix[rows, s2_i]

big_df = pd.DataFrame({'numbers': [],
                       'features': [],
                       'sample': []})

for col in s1_df:
    col_data = s1_df[col]
    slice_df = pd.DataFrame({'numbers':col_data, 
                             'features':rows, 
                             'sample':"s1"})
    big_df = pd.concat([big_df, slice_df])

for col in s2_df:
    col_data = s2_df[col]
    slice_df = pd.DataFrame({'numbers':col_data, 
                             'features':rows, 
                             'sample':"s2"})
    big_df = pd.concat([big_df, slice_df])

big_df
# Out:
#   features    numbers sample
# 4        4  20.209993     s1
# 5        5  18.138757     s1
# 6        6  21.052226     s1
# 4        4  18.144977     s1
# 5        5  15.879583     s1
# 6        6  21.096863     s1
# 4        4  18.179039     s1
# 5        5        NaN     s1
# 6        6  20.753295     s1
# 4        4  19.651518     s2
# 5        5  17.157130     s2
# 6        6  20.911835     s2
# 4        4  19.707679     s2
# 5        5  17.733466     s2
# 6        6  21.165309     s2
# 4        4  20.363331     s2
# 5        5  18.235336     s2
# 6        6  21.409893     s2

# %%
sns.stripplot(data=big_df, x="features", y="numbers", hue="sample")
sns.plt.show()
